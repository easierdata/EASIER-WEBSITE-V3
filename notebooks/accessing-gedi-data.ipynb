# %% [markdown]
# # Front page blurb
#
# Measuring the impact of deforestation is one of the many overarching goals of the [Global Ecosystem Dynamics Investigation](https://gedi.umd.edu/mission/mission-overview/) (GEDI) project. With support of the GEDI's [LIDAR system](https://gedi.umd.edu/mission/technology/) and hitching a ride on the International Space Station, high-quality laser ranging observations collect a 3D structure of the Earths forests for which can be used to estimate the height of forests, the density of vegetation, and providing detail on the Earths carbon cycle. In this blog post, we will  explore the GEDI dataset by leveraging IPFS with the ipfs-stac python library.

# %% [markdown]
# # Introduction
#
# A common thread with geospatial data is its visual nature. But visualization isn’t just limited to imagery—any dataset with a geospatial component can be transformed into a visual format, making complex information easier to grasp. One such format that we'll be exploring today is the [Hierarchical Data Format](https://en.wikipedia.org/wiki/Hierarchical_Data_Format) (HDF5), a scalable and flexible format to store a variety of data types and structures, including multidimensional arrays, tables and metadata.
#
# To provide a sense of how much data GEDI collected, each laser on the lidar system fired off 242 times each second, bouncing off the surface with a 25-meter diameter footprint. Around 16 billion laser pulses per year were continuously collected and an estimated 10 billion cloud-free observations were produced during the 24 month mission. The derived data products in total are ~300TB in size.
#
# ```
# "Existing pan-tropical biomass maps use laser data acquired nearly 15 years ago and were based on less than 5 million laser observations in total. GEDI collects 6 million laser observations every day. So over the tropics, we've already collected about two orders of magnitude more data than what was ‘state-of-the-art' before."
#
# ```
#
#  -- Ralph Dubayah, [GEDI Principal Investigator](https://www.nasa.gov/centers-and-facilities/goddard/nasa-forest-structure-mission-releases-first-data/) and professor of geographical sciences at the UMD.

# %% [markdown]
# # Retrieving GEDI data from IPFS
#
# We'll be exploring the [GEDI L4A](https://cmr.earthdata.nasa.gov/search/concepts/C2237824918-ORNL_CLOUD.html) collection, a data product that's been processed and converted to footprint estimates of above ground biomass density. Let's dive in and see how we can retrieve this data from IPFS using python!
#
# ### Preqrequisites
#
# 1. Install the [IPFS desktop app](https://docs.ipfs.tech/install/ipfs-desktop/#install-instructions) or [Kubo CLI client](https://docs.ipfs.tech/install/command-line/) as this will will allow you to start up a IPFS local node on your machine.
#
#
# 2. Python that's version `3.10.x` or higher as to install our dependencies such as [ipfs-stac](https://pypi.org/project/ipfs-stac/) and [Jupyter Notebook](https://jupyter.org/install#jupyter-notebook).
#
# To get started, save the [libraries](ADD LINK) we'll be using as a text file named `requirements.txt`. I also recommend creating a virtual environment by running the following commands in the terminal.
#
# ``` bash
# python -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt
# ```
#
# Next, start up Jupyter Notebook session by with the following command.
#
# ```bash
# jupyter notebook
# ```
#
# and create a new notebook by clicking on the `New` button and selecting `Python 3`.

# %% [markdown]
# ### Importing the libraries

# %%
import h5py
import geopandas as gpd
from shapely.geometry import MultiPolygon, Polygon
from ipfs_stac import client
import json
import folium

# %% [markdown]
# ### Creating our client object
#
# The `ipfs-stac` library is how we'll be interacting the [Easier STAC API](https://stac.easierdata.info) and communicating with the IPFS network via the [Kubo RPC API](https://docs.ipfs.tech/reference/kubo/rpc/). Below are the properties that we can pass in along with the default assigned values to establish this connection.
#
# A feature that's been added to the `ipfs-stac` library is the ability to start the daemon if it's not already running. We perform this check as the `client` object is initialized.
#
# Let's see what collections are available to us by via our client object.

# %%
easier_client = client.Web3(
    local_gateway="127.0.0.1",
    gateway_port="8081",
    api_port="5001",
    stac_endpoint="https://stac.easierdata.info",
)

easier_client.collections
# Out:
# ['landsat-c2l1', 'GEDI_L4A_AGB_Density_V2_1_2056.v2.1']

# %% [markdown]
# Just like the [Landsat 9 imagery](https://easierdata.org/notebooks/ndvi_stac_ipfs#How-did-we-set-up-the-STAC-API?), we've also prepared a sample set of GEDI data, commonly referred to as **"granules"**.
#
# Let's see how many granules are in the collection id  `GEDI_L4A_AGB_Density_V2_1_2056.v2.1`.

# %%
collection_id = "GEDI_L4A_AGB_Density_V2_1_2056.v2.1"
items = easier_client.searchSTAC(collections=[collection_id])
print(f"The {collection_id} collection has {len(items)} items")
# Out:
# The GEDI_L4A_AGB_Density_V2_1_2056.v2.1 collection has 956 items

# %% [markdown]
# ### Displaying the results

# %% [markdown]
# Let's grab a geojson from IPFS and display it in a map
#
# `harvard.json
#  bafkreib5tmwa7qb2qnm2zqgklsnesjlt4w7uxwbqvbqz7se54t7kxceuu4
#  `

# %%
from folium import FeatureGroup, Figure, FitBounds
import shapely


geojson_cid = "bafkreib5tmwa7qb2qnm2zqgklsnesjlt4w7uxwbqvbqz7se54t7kxceuu4"
geojson_result = easier_client.getFromCID(geojson_cid)

# Convert to json object as to be able to read it with geopandas
geojson = json.loads(geojson_result)
geojson_layer = gpd.GeoDataFrame.from_features(geojson["features"], crs="epsg:4326")

# Create the map centered on the bounds of the first GeoJSON layer
m = folium.Map(scrollWheelZoom=False)
bounds = geojson_layer.total_bounds
m.fit_bounds([[bounds[1], bounds[0]], [bounds[3], bounds[2]]])

# Add the first layer manually using GeoJson
harvard_forests = folium.GeoJson(
    data=geojson,
    name="Geojson from IPFS",
    style_function=lambda feature: {
        "fillColor": "blue",
        "color": "blue",
        "weight": 2,
        "fillOpacity": 0.5,
    },
)

harvard_forests.add_to(m)
# folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# ✅  Fetching bafkreib5tmwa7qb2qnm2zqgklsnesjlt4w7uxwbqvbqz7se54t7kxceuu4 - 0.01/0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894b2f56acdd213b397f11015b2f33f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894b2f56acdd213b397f11015b2f33f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894b2f56acdd213b397f11015b2f33f1 = L.map(
#                 &quot;map_894b2f56acdd213b397f11015b2f33f1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e02ba72c01ea0413c6a296a7d1b6dd11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e02ba72c01ea0413c6a296a7d1b6dd11.addTo(map_894b2f56acdd213b397f11015b2f33f1);
#
#
#             map_894b2f56acdd213b397f11015b2f33f1.fitBounds(
#                 [[42.526614721000044, -72.19471014099997], [42.55210388600006, -72.16807180099994]],
#                 {}
#             );
#
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_93b1bc84e5d1849f04a24a96e694a1f1 = L.geoJson(null, {
#                 onEachFeature: geo_json_93b1bc84e5d1849f04a24a96e694a1f1_onEachFeature,
#
#                 style: geo_json_93b1bc84e5d1849f04a24a96e694a1f1_styler,
#         });
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_add (data) {
#             geo_json_93b1bc84e5d1849f04a24a96e694a1f1
#                 .addData(data);
#         }
#             geo_json_93b1bc84e5d1849f04a24a96e694a1f1_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-72.16974834799998, 42.55210388600006], [-72.16904199099997, 42.54821113500004], [-72.16896873499996, 42.54780864600007], [-72.16880822099995, 42.54691501700006], [-72.16880355199999, 42.54691234300004], [-72.168803225, 42.546912407000036], [-72.16880316299995, 42.54691212200003], [-72.16880208399994, 42.54691150100007], [-72.16880235999997, 42.54690842100006], [-72.16871130099997, 42.54643045400008], [-72.16866550499998, 42.54617905800007], [-72.16859148399993, 42.54576135900005], [-72.16858882799994, 42.54574628800003], [-72.16858528899996, 42.54572621700002], [-72.16855294399994, 42.545543118000076], [-72.16842457599995, 42.54484036000007], [-72.16840547299995, 42.544841461000026], [-72.16839322399994, 42.54475827600004], [-72.16809793899995, 42.544798869000026], [-72.16807180099994, 42.544679638000034], [-72.16825803999997, 42.54461935400008], [-72.16851155199998, 42.54453385200002], [-72.16868654899997, 42.544458383000055], [-72.16886537899995, 42.54432878000005], [-72.16901276099998, 42.54413809600003], [-72.16918872699995, 42.54386125600007], [-72.16935621299996, 42.54362659700006], [-72.16940363399993, 42.54355082100006], [-72.16954128699997, 42.54323352000005], [-72.16968588699996, 42.542806530000064], [-72.16973471099993, 42.54252012500007], [-72.16976536999994, 42.54234848200007], [-72.169789629, 42.54199449700009], [-72.16979701799994, 42.541837056000084], [-72.16978449899995, 42.54169976700006], [-72.16972315099997, 42.541356005000075], [-72.16963824499999, 42.54103979100006], [-72.16936860399994, 42.541038061000044], [-72.16931633999997, 42.54093795200004], [-72.16926415699999, 42.54082760000006], [-72.16911803199997, 42.540507021000046], [-72.16908401799998, 42.54041974700003], [-72.16896833299995, 42.54027033500006], [-72.16888271399995, 42.54011324400005], [-72.16877964399998, 42.53995012200004], [-72.16867731399998, 42.53975446300007], [-72.16850817199997, 42.53938314800006], [-72.16843617399996, 42.53917928300006], [-72.16836511999998, 42.53892771700004], [-72.16833443099995, 42.53874054700002], [-72.16834761399997, 42.538634126000034], [-72.16833301399998, 42.538625932000045], [-72.16840586699993, 42.538376519000046], [-72.16853716399999, 42.53816276200008], [-72.16862791999995, 42.53797282400005], [-72.16881261199995, 42.53767736900006], [-72.16881063899997, 42.53767619800004], [-72.16888773599999, 42.53756184000007], [-72.16894570299996, 42.53724255900005], [-72.16895956199994, 42.53703282600003], [-72.16897446899998, 42.53678997400004], [-72.16895375499996, 42.53664395900005], [-72.16886343499993, 42.53633554000004], [-72.16888976099995, 42.53579549500006], [-72.16905895999997, 42.53544159300002], [-72.16919474299993, 42.53532993400005], [-72.16978869099995, 42.535200

# %%
# Query content from STAC server and process it
granules = easier_client.searchSTAC(
    intersects=geojson["features"][0]["geometry"], collections=[collection_id]
)

print(f"Found {len(granules)} granules that intersect the geojson")
granules_dict = [granule.to_dict() for granule in granules]
granules_geojson = {"type": "FeatureCollection", "features": granules_dict}

# Add as a layer to the map
granules_layer = folium.GeoJson(
    data=granules_geojson,
    name="Granules",
    style_function=lambda feature: {
        "fillColor": "red",  # Orange fill color
        "color": "black",  # Orange border color
        "weight": 5,  # Border width
        "opacity": 0.1,  # Border opacity
        "fillOpacity": 0.01,  # Fill opacity
    },
)

granules_layer.add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# Found 29 granules that intersect the geojson
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894b2f56acdd213b397f11015b2f33f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894b2f56acdd213b397f11015b2f33f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894b2f56acdd213b397f11015b2f33f1 = L.map(
#                 &quot;map_894b2f56acdd213b397f11015b2f33f1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e02ba72c01ea0413c6a296a7d1b6dd11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e02ba72c01ea0413c6a296a7d1b6dd11.addTo(map_894b2f56acdd213b397f11015b2f33f1);
#
#
#             map_894b2f56acdd213b397f11015b2f33f1.fitBounds(
#                 [[42.526614721000044, -72.19471014099997], [42.55210388600006, -72.16807180099994]],
#                 {}
#             );
#
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_93b1bc84e5d1849f04a24a96e694a1f1 = L.geoJson(null, {
#                 onEachFeature: geo_json_93b1bc84e5d1849f04a24a96e694a1f1_onEachFeature,
#
#                 style: geo_json_93b1bc84e5d1849f04a24a96e694a1f1_styler,
#         });
#
#         function geo_json_93b1bc84e5d1849f04a24a96e694a1f1_add (data) {
#             geo_json_93b1bc84e5d1849f04a24a96e694a1f1
#                 .addData(data);
#         }
#             geo_json_93b1bc84e5d1849f04a24a96e694a1f1_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-72.16974834799998, 42.55210388600006], [-72.16904199099997, 42.54821113500004], [-72.16896873499996, 42.54780864600007], [-72.16880822099995, 42.54691501700006], [-72.16880355199999, 42.54691234300004], [-72.168803225, 42.546912407000036], [-72.16880316299995, 42.54691212200003], [-72.16880208399994, 42.54691150100007], [-72.16880235999997, 42.54690842100006], [-72.16871130099997, 42.54643045400008], [-72.16866550499998, 42.54617905800007], [-72.16859148399993, 42.54576135900005], [-72.16858882799994, 42.54574628800003], [-72.16858528899996, 42.54572621700002], [-72.16855294399994, 42.545543118000076], [-72.16842457599995, 42.54484036000007], [-72.16840547299995, 42.544841461000026], [-72.16839322399994, 42.54475827600004], [-72.16809793899995, 42.544798869000026], [-72.16807180099994, 42.544679638000034], [-72.16825803999997, 42.54461935400008], [-72.16851155199998, 42.54453385200002], [-72.16868654899997, 42.544458383000055], [-72.16886537899995, 42.54432878000005], [-72.16901276099998, 42.54413809600003], [-72.16918872699995, 42.54386125600007], [-72.16935621299996, 42.54362659700006], [-72.16940363399993, 42.54355082100006], [-72.16954128699997, 42.54323352000005], [-72.16968588699996, 42.542806530000064], [-72.16973471099993, 42.54252012500007], [-72.16976536999994, 42.54234848200007], [-72.169789629, 42.54199449700009], [-72.16979701799994, 42.541837056000084], [-72.16978449899995, 42.54169976700006], [-72.16972315099997, 42.541356005000075], [-72.16963824499999, 42.54103979100006], [-72.16936860399994, 42.541038061000044], [-72.16931633999997, 42.54093795200004], [-72.16926415699999, 42.54082760000006], [-72.16911803199997, 42.540507021000046], [-72.16908401799998, 42.54041974700003], [-72.16896833299995, 42.54027033500006], [-72.16888271399995, 42.54011324400005], [-72.16877964399998, 42.53995012200004], [-72.16867731399998, 42.53975446300007], [-72.16850817199997, 42.53938314800006], [-72.16843617399996, 42.53917928300006], [-72.16836511999998, 42.53892771700004], [-72.16833443099995, 42.53874054700002], [-72.16834761399997, 42.538634126000034], [-72.16833301399998, 42.538625932000045], [-72.16840586699993, 42.538376519000046], [-72.16853716399999, 42.53816276200008], [-72.16862791999995, 42.53797282400005], [-72.16881261199995, 42.53767736900006], [-72.16881063899997, 42.53767619800004], [-72.16888773599999, 42.53756184000007], [-72.16894570299996, 42.53724255900005], [-72.16895956199994, 42.53703282600003], [-72.16897446899998, 42.53678997400004], [-72.16895375499996, 42.53664395900005], [-72.16886343499993, 42.53633554000004], [-72.16888976099995, 42.53579549500006], [-72.16905895999997, 42.53544159300002], [-72.16919474299993, 42.53532993400005], [-72.16978869099995, 42.535200

# %% [markdown]
# # EXTRA CONTENT - WILL NOT BE INCLUDED IN THE FINAL BLOG POST

# %%
import folium
import geopandas as gpd
from shapely.geometry import Polygon, LineString, MultiLineString
from scipy.spatial import Voronoi
import numpy as np
import pygeoops


# Function to extract left and right sides of a polygon and create center lines
def create_center_lines(polygon):
    # Get the exterior coordinates of the polygon
    exterior_coords = list(polygon.exterior.coords)

    # Find the leftmost and rightmost points
    leftmost = min(exterior_coords, key=lambda x: x[0])
    rightmost = max(exterior_coords, key=lambda x: x[0])

    # Create lines from these points
    left_line = LineString([leftmost, (leftmost[0], polygon.centroid.y)])
    right_line = LineString([rightmost, (rightmost[0], polygon.centroid.y)])

    return left_line, right_line


# Function to generate the medial axis of a polygon
def medial_axis(polygon):
    # Get the exterior coordinates of the polygon
    exterior_coords = np.array(polygon.exterior.coords)

    # Generate the Voronoi diagram
    vor = Voronoi(exterior_coords)

    # Extract the medial axis (edges of the Voronoi diagram inside the polygon)
    lines = []
    for ridge in vor.ridge_vertices:
        if -1 not in ridge:
            line = LineString([vor.vertices[ridge[0]], vor.vertices[ridge[1]]])
            if polygon.contains(line):
                lines.append(line)

    return lines


# Function to extract the central line from the medial axis
def central_line(medial_axis):
    # Simplify the medial axis to get a single central line
    # This is a heuristic approach and may need adjustment based on the polygon shape
    longest_line = max(medial_axis, key=lambda line: line.length)
    return longest_line


# Iterate over each feature in the GeoDataFrame
center_lines = []
for feature in granules_layer.geometry:
    if isinstance(feature, Polygon):
        centerline = pygeoops.centerline(feature)
        center_lines.append(centerline)

# Create a GeoDataFrame for the center lines
center_lines_gdf = gpd.GeoDataFrame(geometry=center_lines, crs="epsg:4326")

# Add the center lines to the Folium map
for line in center_lines_gdf.geometry:
    folium.GeoJson(
        line.__geo_interface__, style_function=lambda x: {"color": "blue", "weight": 2}
    ).add_to(m)

# Save the map to an HTML file
m.save("map_with_center_lines.html")

# %%
import pygeoops


# gdf.geometry = pygeoops.centerline(gdf.geometry)
centerline = pygeoops.centerline(granules_layer.geometry)

# %%
center_lines = []
for feature in granules_layer.geometry[:20]:
    if isinstance(feature, Polygon):
        feat = pygeoops.centerline(feature)
        center_lines.append(feat)

# %%
# Define a style function for the GeoJSON layer
def style_function(feature):
    return {
        "fillColor": "#ff7800",  # Orange fill color
        "color": "#ff7800",  # Orange border color
        "fillOpacity": 0.5,  # Fill opacity
    }


granules = easier_client.searchSTAC(
    intersects=geojson["features"][0]["geometry"], collections=[collection_id]
)

print(f"Found {len(granules)} granules that intersect the geojson")
granules_dict = [granule.to_dict() for granule in granules]
granules_layer = gpd.GeoDataFrame.from_features(granules_dict)
granules_layer.crs = "epsg:4326"
# Add the second GeoDataFrame to the folium map
folium.GeoJson(granules_layer.__geo_interface__, name="Intersecting Granules").add_to(m)
# folium.LayerControl().add_to(m)
m.save("footprint.html")
m

# %% [markdown]
# ### EXTRA TEXT
#
# When we talk about geospatial data, it's not just one kind—it's a whole mix of forms. Satellite imagery giving us visual insights from above and tabular data organizing info into neat rows and columns, each form adding a different layer to our understanding of the world.
#
#
# The ability to measure the height of forests and the density of vegetation is critical for understanding the impact of deforestation on the environment. The GEDI project is a collaboration between the University of Maryland (UMD) and NASA Goddard Space Flight Center. The GEDI mission is to characterize the dynamics of Earth's ecosystems and surface topography using a laser ranging instrument on the International Space Station (ISS). The GEDI instrument provides high-quality laser ranging observations of the 3D structure of the Earth. The data collected by GEDI can be used to estimate the height of forests, the density of vegetation, and the impact of deforestation on the environment.
#
# The GEDI project is a collaboration between the University of Maryland (UMD) and NASA Goddard Space Flight Center. The GEDI mission is to characterize the dynamics of Earth's ecosystems and surface topography using a laser ranging instrument on the International Space Station (ISS). The GEDI instrument provides high-quality laser ranging observations of the 3D structure of the Earth. The data collected by GEDI can be used to estimate the height of forests, the density of vegetation, and the impact of deforestation on the environment.
#
#
#
# The GEDIproject led by the University of Maryland (UMD) in collaboration with NASA Goddard Space .
#
# The GEDI mission is to characterize the dynamics of Earth's ecosystems and surface topography using a laser ranging instrument on the International Space Station (ISS). The GEDI instrument provides high-quality laser ranging observations of the 3D structure of the Earth. The data collected by GEDI can be used to estimate the height of forests, the density of vegetation, and the impact of deforestation on the environment.
#
# a file format designed to store and organize large amounts of data. HDF files are commonly used in scientific research and data analysis to store and share data in a structured format. HDF files can store a wide range of data types, including images, tables, and arrays, making them a versatile tool for working with complex datasets.
